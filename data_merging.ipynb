# %%
import numpy as np

import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import seaborn as sns

# %%
crash = pd.read_csv('crashes_columns_eleminated.csv')
casualties = pd.read_csv('casualties_columns_eleminated.csv')

# %%
merge1=pd.merge(crash,casualties,how='right',on='Crash_Ref_Number')

# %%
merge1
# Out:
#         Unnamed: 0_x  Crash_Ref_Number  factors_Ref_Number  \
# 0             227555            227556              227556
# 1             227556            227557              227557
# 2             227557            227558              227558
# 3             227558            227559              227559
# 4             227559            227560              227560
# ...              ...               ...                 ...
# 126091        353646            353647              353647
# 126092        353647            353648              353648
# 126093        353648            353649              353649
# 126094        353649            353650              353650
# 126095        353650            353651              353651
#
#         Condition_Ref_Number     Crash_Severity  Crash_Year Crash_Month  \
# 0                     227556  Medical treatment        2011     January
# 1                     227557  Medical treatment        2011     January
# ...

# %%
merge1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 126096 entries, 0 to 126095
# Data columns (total 14 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0_x          126096 non-null  int64
#  1   Crash_Ref_Number      126096 non-null  int64
#  2   factors_Ref_Number    126096 non-null  int64
#  3   Condition_Ref_Number  126096 non-null  int64
#  4   Crash_Severity        126096 non-null  object
#  5   Crash_Year            126096 non-null  int64
#  6   Crash_Month           126096 non-null  object
#  7   Crash_Day_Of_Week     126096 non-null  object
#  8   Crash_Region          126096 non-null  object
#  9   Total_Casualties      126096 non-null  int64
#  10  Unnamed: 0_y          126096 non-null  int64
#  11  AgeGroup              126096 non-null  object
#  12  Gender                126096 non-null  object
#  13  RoadUserType          126096 non-null  object
# dtypes: int64(7), object(7)
# ...

# %%
demographics = pd.read_csv('demographics_columns_eleminated.csv')

# %%
merge2=pd.merge(merge1,demographics,how='right',on='Crash_Ref_Number')

# %%
merge2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 126096 entries, 0 to 126095
# Data columns (total 27 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Unnamed: 0_x                        126096 non-null  int64
#  1   Crash_Ref_Number                    126096 non-null  int64
#  2   factors_Ref_Number                  126096 non-null  int64
#  3   Condition_Ref_Number                126096 non-null  int64
#  4   Crash_Severity                      126096 non-null  object
#  5   Crash_Year                          126096 non-null  int64
#  6   Crash_Month                         126096 non-null  object
#  7   Crash_Day_Of_Week                   126096 non-null  object
#  8   Crash_Region                        126096 non-null  object
#  9   Total_Casualties                    126096 non-null  int64
#  10  Unnamed: 0_y                        126096 non-null  int64
# ...

# %%
cac = pd.read_csv('circumstances_and_conditions_columns_eleminated.csv')

# %%
cac
# Out:
#         Unnamed: 0  Condition_Ref_Number Crash_Nature      Crash_Type  \
# 0           227555                227556     Rear-end   Multi-Vehicle
# 1           227556                227557        Angle   Multi-Vehicle
# 2           227557                227558        Angle   Multi-Vehicle
# 3           227558                227559        Angle   Multi-Vehicle
# 4           227559                227560   Hit object  Single Vehicle
# ...            ...                   ...          ...             ...
# 126091      353646                353647        Angle   Multi-Vehicle
# 126092      353647                353648   Hit object  Single Vehicle
# 126093      353648                353649     Rear-end   Multi-Vehicle
# 126094      353649                353650        Angle   Multi-Vehicle
# 126095      353650                353651        Angle   Multi-Vehicle
#
#            Crash_Traffic_Control  Count_Unit_Car  Count_Unit_Motorcycle_Moped  \
# ...

# %%
cac1=cac.rename(columns={'Condition_Ref_Number': 'Crash_Ref_Number'})

# %%
merge3=pd.merge(merge2,cac1,how='right',on='Crash_Ref_Number')
# Out:
# C:\Users\tanvr\AppData\Local\Temp/ipykernel_26180/2453487877.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Unnamed: 0_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merge3=pd.merge(merge2,cac1,how='right',on='Crash_Ref_Number')

# %%
merge3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 126096 entries, 0 to 126095
# Data columns (total 38 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Unnamed: 0_x                        126096 non-null  int64
#  1   Crash_Ref_Number                    126096 non-null  int64
#  2   factors_Ref_Number                  126096 non-null  int64
#  3   Condition_Ref_Number                126096 non-null  int64
#  4   Crash_Severity                      126096 non-null  object
#  5   Crash_Year                          126096 non-null  int64
#  6   Crash_Month                         126096 non-null  object
#  7   Crash_Day_Of_Week                   126096 non-null  object
#  8   Crash_Region                        126096 non-null  object
#  9   Total_Casualties                    126096 non-null  int64
#  10  Unnamed: 0_y                        126096 non-null  int64
# ...

# %%
fnf = pd.read_csv('factors_and_features_columns_eleminated.csv')

# %%
fnf1=fnf.rename(columns={'factors_Ref_Number': 'Crash_Ref_Number'})

# %%
fnf1
# Out:
#         Unnamed: 0  Crash_Ref_Number  Crash_Hour         Crash_Street  \
# 0           227555            227556          17  Mt Lindesay Art. Rd
# 1           227556            227557           9         Beenleigh Rd
# 2           227557            227558          20           Compton Rd
# 3           227558            227559          14           Bradman St
# 4           227559            227560          16         Beenleigh Rd
# ...            ...               ...         ...                  ...
# 126091      353646            353647           5          Cuthbert Dr
# 126092      353647            353648           9   Black Diamond Cres
# 126093      353648            353649          11               Guy St
# 126094      353649            353650          11            Albion St
# 126095      353650            353651           8              Gore St
#
#                          City    Main_Roads_Region            Roadway_Feature  \
# ...

# %%
merge4=pd.merge(merge3,fnf1,how='right',on='Crash_Ref_Number')

# %%
merge4
# Out:
#         Unnamed: 0_x  Crash_Ref_Number  factors_Ref_Number  \
# 0             227555            227556              227556
# 1             227556            227557              227557
# 2             227557            227558              227558
# 3             227558            227559              227559
# 4             227559            227560              227560
# ...              ...               ...                 ...
# 126091        353646            353647              353647
# 126092        353647            353648              353648
# 126093        353648            353649              353649
# 126094        353649            353650              353650
# 126095        353650            353651              353651
#
#         Condition_Ref_Number     Crash_Severity  Crash_Year Crash_Month  \
# 0                     227556  Medical treatment        2011     January
# 1                     227557  Medical treatment        2011     January
# ...

# %%
merge4.to_csv("crashes_merged_file.csv")
