# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import seaborn as sns

# %%
# loading the .csv file.
demographics=pd.read_excel('3_demographics.csv')

# %%
demographics.head()
# Out:
#    Crash_Ref_Number Involving_Male_Driver Involving_Female_Driver  \
# 0                 1                    No                      No
# 1                 2                    No                     Yes
# 2                 3                    No                     Yes
# 3                 4                    No                     Yes
# 4                 5                    No                     Yes
#
#   Involving_Young_Driver_16-24 Involving_Senior_Driver_60plus  \
# 0                           No                             No
# 1                           No                             No
# 2                           No                            Yes
# 3                           No                            Yes
# 4                           No                            Yes
#
#   Involving_Provisional_Driver Involving_Overseas_Licensed_Driver  \
# 0                           No                                 No
# ...

# %%
demographics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330125 entries, 0 to 330124
# Data columns (total 13 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Crash_Ref_Number                    330125 non-null  int64
#  1   Involving_Male_Driver               330125 non-null  object
#  2   Involving_Female_Driver             330125 non-null  object
#  3   Involving_Young_Driver_16-24        330125 non-null  object
#  4   Involving_Senior_Driver_60plus      330125 non-null  object
#  5   Involving_Provisional_Driver        330125 non-null  object
#  6   Involving_Overseas_Licensed_Driver  330125 non-null  object
#  7   Involving_Unlicensed_Driver         330125 non-null  object
#  8   Count_Crashes                       330125 non-null  int64
#  9   Count_Casualty_Fatality             330125 non-null  int64
#  10  Count_Casualty_Hospitalised         330125 non-null  int64
# ...

# %%
#checking for missing values
demographics.isnull().sum()
# Out:
# Crash_Ref_Number                      0
# Involving_Male_Driver                 0
# Involving_Female_Driver               0
# Involving_Young_Driver_16-24          0
# Involving_Senior_Driver_60plus        0
# Involving_Provisional_Driver          0
# Involving_Overseas_Licensed_Driver    0
# Involving_Unlicensed_Driver           0
# Count_Crashes                         0
# Count_Casualty_Fatality               0
# Count_Casualty_Hospitalised           0
# Count_Casualty_MedicallyTreated       0
# Count_Casualty_MinorInjury            0
# dtype: int64

# %%
print(demographics)
# Out:
#         Crash_Ref_Number Involving_Male_Driver Involving_Female_Driver  \
# 0                      1                    No                      No
# 1                      2                    No                     Yes
# 2                      3                    No                     Yes
# 3                      4                    No                     Yes
# 4                      5                    No                     Yes
# ...                  ...                   ...                     ...
# 330120            353647                   Yes                      No
# 330121            353648                   Yes                      No
# 330122            353649                   Yes                      No
# 330123            353650                   Yes                     Yes
# 330124            353651                   Yes                     Yes
#
#        Involving_Young_Driver_16-24 Involving_Senior_Driver_60plus  \
# ...

# %%
demographics_columns_renamed=demographics.rename(columns={'Count_Crashes': 'Crashes_Count', 'Count_Casualty_Fatality':'Fatalities', 'Count_Casualty_Hospitalised':'Hospitalised_Casualties', 'Count_Casualty_MedicallyTreated':'MedicallyTreated_Casualties', 'Count_Casualty_MinorInjury':'Casualties_with_MinorInjury'})

# %%
print(demographics_columns_renamed)
# Out:
#         Crash_Ref_Number Involving_Male_Driver Involving_Female_Driver  \
# 0                      1                    No                      No
# 1                      2                    No                     Yes
# 2                      3                    No                     Yes
# 3                      4                    No                     Yes
# 4                      5                    No                     Yes
# ...                  ...                   ...                     ...
# 330120            353647                   Yes                      No
# 330121            353648                   Yes                      No
# 330122            353649                   Yes                      No
# 330123            353650                   Yes                     Yes
# 330124            353651                   Yes                     Yes
#
#        Involving_Young_Driver_16-24 Involving_Senior_Driver_60plus  \
# ...

# %%
print(demographics)
# Out:
#         Crash_Ref_Number Involving_Male_Driver Involving_Female_Driver  \
# 0                      1                    No                      No
# 1                      2                    No                     Yes
# 2                      3                    No                     Yes
# 3                      4                    No                     Yes
# 4                      5                    No                     Yes
# ...                  ...                   ...                     ...
# 330120            353647                   Yes                      No
# 330121            353648                   Yes                      No
# 330122            353649                   Yes                      No
# 330123            353650                   Yes                     Yes
# 330124            353651                   Yes                     Yes
#
#        Involving_Young_Driver_16-24 Involving_Senior_Driver_60plus  \
# ...

# %%
demographics_columns_renamed.to_csv("demographics.csv")
